# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

file = pd.read_excel('C:/Data_/excel/data_jobs_salary_all.xlsx',sheet_name='maaz_1')
print(file)
# Out:
#                  job_title_short  \
# 0          Senior Data Scientist
# 1                  Data Engineer
# 2            Senior Data Analyst
# 3      Machine Learning Engineer
# 4                 Data Scientist
# ...                          ...
# 32667      Senior Data Scientist
# 32668               Data Analyst
# 32669             Data Scientist
# 32670               Data Analyst
# 32671             Data Scientist
#
#                                                job_title     job_location  \
# 0      Senior Data Scientist Data and Analytics Perfo...   Bennington, NE
# 1                                     Data Engineer - MA         Mesa, AZ
# 2      Supervisory Information Technology Specialist ...   Alexandria, VA
# 3                    Machine Learning Research Scientist   Pittsburgh, PA
# 4                                    Data Scientist, AWS       Irving, TX
# ...                                                  ...              ...
# ...

# %%
file.index.name='job_id'   #None will remove the index column
file
#file['job_title_short'].value_counts().plot(kind='barh').
# Out:
#                   job_title_short  \
# job_id
# 0           Senior Data Scientist
# 1                   Data Engineer
# 2             Senior Data Analyst
# 3       Machine Learning Engineer
# 4                  Data Scientist
# ...                           ...
# 32667       Senior Data Scientist
# 32668                Data Analyst
# 32669              Data Scientist
# 32670                Data Analyst
# 32671              Data Scientist
#
#                                                 job_title     job_location  \
# job_id
# 0       Senior Data Scientist Data and Analytics Perfo...   Bennington, NE
# 1                                      Data Engineer - MA         Mesa, AZ
# 2       Supervisory Information Technology Specialist ...   Alexandria, VA
# 3                     Machine Learning Research Scientist   Pittsburgh, PA
# 4                                     Data Scientist, AWS       Irving, TX
# ...                                                   ...              ...
# ...

# %%
file.index.name=None
file_USA=file[file['job_country']=='United States']
file_USA.reset_index(inplace=True)  #reset_index will starreplacet the index where a skip value occur by the following.
file_USA
# Out:
#        index            job_title_short  \
# 0          1              Data Engineer
# 1          2        Senior Data Analyst
# 2          3  Machine Learning Engineer
# 3          4             Data Scientist
# 4          6              Data Engineer
# ...      ...                        ...
# 25136  32666             Data Scientist
# 25137  32667      Senior Data Scientist
# 25138  32668               Data Analyst
# 25139  32669             Data Scientist
# 25140  32670               Data Analyst
#
#                                                job_title    job_location  \
# 0                                     Data Engineer - MA        Mesa, AZ
# 1      Supervisory Information Technology Specialist ...  Alexandria, VA
# 2                    Machine Learning Research Scientist  Pittsburgh, PA
# 3                                    Data Scientist, AWS      Irving, TX
# 4                             Sr. Data Engineer (remote)        Anywhere
# ...
